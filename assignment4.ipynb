# %% [markdown]
# # Deep Learning
# ## Assignment 4
# Previously in assignments 2 and 3, we trained fully connected networks to classify notMNIST characters.
# The goal of this assignment is make the neural network convolutional.

# %%
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %% [markdown]
# First reload the data we generated in assignment1.ipynb.

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
    save = pickle.load(f)
    train_dataset = save['train_dataset']
    train_labels = save['train_labels']
    valid_dataset = save['valid_dataset']
    valid_labels = save['valid_labels']
    test_dataset = save['test_dataset']
    test_labels = save['test_labels']
    del save  # hint to help gc free up memory
    print('Training set', train_dataset.shape, train_labels.shape)
    print('Validation set', valid_dataset.shape, valid_labels.shape)
    print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %% [markdown]
# Reformat into a TensorFlow-friendly shape:
# * convolutions need the image data formatted as a cube (width by height by #channels)
# * labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
    dataset = dataset.reshape((-1, image_size, image_size, num_channels)).astype(np.float32)
    labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
    return dataset, labels

train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28, 1) (200000, 10)
# Validation set (10000, 28, 28, 1) (10000, 10)
# Test set (10000, 28, 28, 1) (10000, 10)

# %%
def accuracy(predictions, labels):
    return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1)) / predictions.shape[0])

# %% [markdown]
# Let's build a small network with two convolutional layers, followed by one fully connected layer. Convolutional networks are more expensive computationally, so we'll limit its depth and number of fully connected nodes.

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data
    tf_train_dataset = tf.placeholder(tf.float32, shape=(batch_size, image_size, image_size, num_channels))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)
  
  # Variables
    layer1_weights = tf.Variable(tf.truncated_normal(
        [patch_size, patch_size, num_channels, depth], stddev=0.1))
    layer1_biases = tf.Variable(tf.zeros([depth]))
    layer2_weights = tf.Variable(tf.truncated_normal(
        [patch_size, patch_size, depth, depth], stddev=0.1))
    layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
    layer3_weights = tf.Variable(tf.truncated_normal(
        [(image_size // 4) * (image_size // 4) * depth, num_hidden], stddev=0.1))
    layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
    layer4_weights = tf.Variable(tf.truncated_normal(
        [num_hidden, num_labels], stddev=0.1))
    layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model
    def model(data):
        conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
        hidden = tf.nn.relu(conv + layer1_biases)
        conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
        hidden = tf.nn.relu(conv + layer2_biases)
        shape = hidden.get_shape().as_list()
        reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
        hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
        return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
    logits = model(tf_train_dataset)
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
    optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)
    valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
    test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    for step in range(num_steps):
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        feed_dict = {tf_train_dataset: batch_data, tf_train_labels: batch_labels}
        _, l, predictions = session.run([optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 50 == 0):
            print('Minibatch loss at step %d: %f' % (step, l))
            print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
            print('Validation accuracy: %.1f%%' % accuracy(valid_prediction.eval(), valid_labels))
    print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.292991
# Minibatch accuracy: 18.8%
# Validation accuracy: 9.9%
# Minibatch loss at step 50: 1.957063
# Minibatch accuracy: 25.0%
# Validation accuracy: 42.7%
# Minibatch loss at step 100: 1.299799
# Minibatch accuracy: 50.0%
# Validation accuracy: 60.6%
# Minibatch loss at step 150: 0.396374
# Minibatch accuracy: 87.5%
# Validation accuracy: 74.1%
# Minibatch loss at step 200: 0.855679
# Minibatch accuracy: 68.8%
# Validation accuracy: 77.4%
# Minibatch loss at step 250: 1.011208
# Minibatch accuracy: 68.8%
# Validation accuracy: 78.2%
# Minibatch loss at step 300: 0.423037
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.3%
# Minibatch loss at step 350: 0.649353
# Minibatch accuracy: 93.8%
# Validation accuracy: 77.6%
# Minibatch loss at step 400: 0.235130
# Minibatch accuracy: 100.0%
# Validation accuracy: 80.1%
# Minibatch loss at step 450: 0.945403
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.6%
# Minibatch loss at step 500: 0.644435
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.0%
# Minibatch loss at step 550: 0.674276
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.7%
# Minibatch loss at step 600: 0.279602
# Minibatch accuracy: 93.8%
# Validation accuracy: 81.6%
# Minibatch loss at step 650: 0.920380
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.4%
# Minibatch loss at step 700: 1.036268
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.9%
# Minibatch loss at step 750: 0.115223
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.1%
# Minibatch loss at step 800: 0.626765
# Minibatch accuracy: 68.8%
# Validation accuracy: 82.3%
# Minibatch loss at step 850: 0.718619
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.8%
# Minibatch loss at step 900: 0.599370
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.0%
# Minibatch loss at step 950: 0.586771
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.9%
# Minibatch loss at step 1000: 0.274058
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.5%
# Test accuracy: 89.9%

# %% [markdown]
# ## Problem 1
# The convolutional model above uses convolutions with stride 2 to reduce the dimensionality. Let's replace the strides by a max pooling operation (`nn.max_pool()`) of stride 2 and kernel size 2.

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data
    tf_train_dataset = tf.placeholder(tf.float32, shape=(batch_size, image_size, image_size, num_channels))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)
  
  # Variables
    layer1_weights = tf.Variable(tf.truncated_normal(
        [patch_size, patch_size, num_channels, depth], stddev=0.1))
    layer1_biases = tf.Variable(tf.zeros([depth]))
    layer2_weights = tf.Variable(tf.truncated_normal(
        [patch_size, patch_size, depth, depth], stddev=0.1))
    layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
    layer3_weights = tf.Variable(tf.truncated_normal(
        [(image_size // 4) * (image_size // 4) * depth, num_hidden], stddev=0.1))
    layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
    layer4_weights = tf.Variable(tf.truncated_normal(
        [num_hidden, num_labels], stddev=0.1))
    layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model
    def model(data):
        conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
        hidden = tf.nn.relu(conv + layer1_biases)
        hidden = tf.nn.max_pool(hidden, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
        conv = tf.nn.conv2d(hidden, layer2_weights, [1, 1, 1, 1], padding='SAME')
        hidden = tf.nn.relu(conv + layer2_biases)
        hidden = tf.nn.max_pool(hidden, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
        shape = hidden.get_shape().as_list()
        reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
        hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
        return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
    logits = model(tf_train_dataset)
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
    optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)
    valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
    test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    for step in range(num_steps):
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        feed_dict = {tf_train_dataset: batch_data, tf_train_labels: batch_labels}
        _, l, predictions = session.run([optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 50 == 0):
            print('Minibatch loss at step %d: %f' % (step, l))
            print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
            print('Validation accuracy: %.1f%%' % accuracy(valid_prediction.eval(), valid_labels))
    print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 2.821946
# Minibatch accuracy: 18.8%
# Validation accuracy: 13.5%
# Minibatch loss at step 50: 1.563737
# Minibatch accuracy: 37.5%
# Validation accuracy: 42.8%
# Minibatch loss at step 100: 1.211799
# Minibatch accuracy: 56.2%
# Validation accuracy: 60.6%
# Minibatch loss at step 150: 0.319023
# Minibatch accuracy: 93.8%
# Validation accuracy: 74.1%
# Minibatch loss at step 200: 0.891898
# Minibatch accuracy: 75.0%
# Validation accuracy: 78.0%
# Minibatch loss at step 250: 1.340669
# Minibatch accuracy: 62.5%
# Validation accuracy: 78.0%
# Minibatch loss at step 300: 0.386048
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.2%
# Minibatch loss at step 350: 0.551212
# Minibatch accuracy: 87.5%
# Validation accuracy: 76.6%
# Minibatch loss at step 400: 0.222526
# Minibatch accuracy: 100.0%
# Validation accuracy: 80.3%
# Minibatch loss at step 450: 0.764847
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.8%
# Minibatch loss at step 500: 0.602545
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.8%
# Minibatch loss at step 550: 0.733621
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.7%
# Minibatch loss at step 600: 0.264816
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.1%
# Minibatch loss at step 650: 0.880742
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.2%
# Minibatch loss at step 700: 0.954239
# Minibatch accuracy: 62.5%
# Validation accuracy: 83.9%
# Minibatch loss at step 750: 0.123536
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.3%
# Minibatch loss at step 800: 0.490204
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.8%
# Minibatch loss at step 850: 0.824479
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.2%
# Minibatch loss at step 900: 0.547984
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.4%
# Minibatch loss at step 950: 0.422715
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.6%
# Minibatch loss at step 1000: 0.320234
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.2%
# Test accuracy: 90.7%

# %% [markdown]
# ## Problem 2
# Let's try to get the best performance we can using a convolutional net. We can take a look at the classic [LeNet5](http://yann.lecun.com/exdb/lenet/) architecture, add Dropout, and/or adding learning rate decay.

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data
    tf_train_dataset = tf.placeholder(tf.float32, shape=(batch_size, image_size, image_size, num_channels))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)
  
  # Variables
    layer1_weights = tf.Variable(tf.truncated_normal(
        [patch_size, patch_size, num_channels, depth], stddev=0.1))
    layer1_biases = tf.Variable(tf.zeros([depth]))
    layer2_weights = tf.Variable(tf.truncated_normal(
        [patch_size, patch_size, depth, depth], stddev=0.1))
    layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
    layer3_weights = tf.Variable(tf.truncated_normal(
        [(image_size // 4) * (image_size // 4) * depth, num_hidden], stddev=0.1))
    layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
    layer4_weights = tf.Variable(tf.truncated_normal(
        [num_hidden, num_labels], stddev=0.1))
    layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
    global_step = tf.Variable(0)  # count the number of steps taken.
  
  # Model
    def model(data, keep_prob):
        conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
        hidden = tf.nn.relu(conv + layer1_biases)
        hidden = tf.nn.max_pool(hidden, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
        conv = tf.nn.conv2d(hidden, layer2_weights, [1, 1, 1, 1], padding='SAME')
        hidden = tf.nn.relu(conv + layer2_biases)
        hidden = tf.nn.max_pool(hidden, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
        shape = hidden.get_shape().as_list()
        reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
        hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
        hidden = tf.nn.dropout(hidden, keep_prob)
        return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
    logits = model(tf_train_dataset, 0.5)
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
    learning_rate = tf.train.exponential_decay(0.1, global_step, decay_steps=100, decay_rate=0.95)
    optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)
  
  # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(model(tf_train_dataset, 1.0))
    valid_prediction = tf.nn.softmax(model(tf_valid_dataset, 1.0))
    test_prediction = tf.nn.softmax(model(tf_test_dataset, 1.0))

# %%
num_steps = 4001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    for step in range(num_steps):
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        feed_dict = {tf_train_dataset: batch_data, tf_train_labels: batch_labels}
        _, l, predictions, lr = session.run([optimizer, loss, train_prediction, learning_rate], feed_dict=feed_dict)
        if (step % 250 == 0):
            print('Minibatch loss at step %d: %f' % (step, l))
            print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
            print('Validation accuracy: %.1f%%' % accuracy(valid_prediction.eval(), valid_labels))
            print('Learning rate: %.3f' % lr)
    print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.864172
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Learning rate: 0.100
# Minibatch loss at step 250: 1.651018
# Minibatch accuracy: 62.5%
# Validation accuracy: 71.8%
# Learning rate: 0.088
# Minibatch loss at step 500: 0.768321
# Minibatch accuracy: 93.8%
# Validation accuracy: 81.7%
# Learning rate: 0.077
# Minibatch loss at step 750: 0.157670
# Minibatch accuracy: 100.0%
# Validation accuracy: 83.3%
# Learning rate: 0.068
# Minibatch loss at step 1000: 0.466590
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.8%
# Learning rate: 0.060
# Minibatch loss at step 1250: 0.728192
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.8%
# Learning rate: 0.053
# Minibatch loss at step 1500: 0.788513
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.6%
# Learning rate: 0.046
# Minibatch loss at step 1750: 0.725065
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.6%
# Learning rate: 0.041
# Minibatch loss at step 2000: 0.165773
# Minibatch accuracy: 100.0%
# Validation accuracy: 85.5%
# Learning rate: 0.036
# Minibatch loss at step 2250: 0.347613
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.8%
# Learning rate: 0.032
# Minibatch loss at step 2500: 0.913716
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.5%
# Learning rate: 0.028
# Minibatch loss at step 2750: 2.034117
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.2%
# Learning rate: 0.024
# Minibatch loss at step 3000: 0.944740
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.3%
# Learning rate: 0.021
# Minibatch loss at step 3250: 0.400486
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.6%
# Learning rate: 0.019
# Minibatch loss at step 3500: 0.505975
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.8%
# Learning rate: 0.017
# Minibatch loss at step 3750: 0.790070
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.6%
# Learning rate: 0.015
# Minibatch loss at step 4000: 0.510757
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.7%
# Learning rate: 0.013
# Test accuracy: 93.3%
